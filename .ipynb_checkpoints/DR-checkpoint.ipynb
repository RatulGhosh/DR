# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image
import scipy as sc
from skimage import transform
# Out:
# /home/ratul/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
from os import listdir
from os.path import isfile, join
path1 = 'data/symptoms_new/'
path2 = 'data/nosymptoms_new/'
file_pos = [path1+f for f in listdir(path1) if isfile(join(path1, f)) and f[-4:] == 'jpeg']
file_neg = [path2+f for f in listdir(path2) if isfile(join(path2, f)) and f[-4:] == 'jpeg']

# %%
len(file_pos), len(file_neg)
# Out:
# (595, 1468)

# %%
import pandas as pd
file = pd.DataFrame()
file['location'] = file_pos

# %%
file
# Out:
#                               location
# 0     data/symptoms_new16576_left.jpeg
# 1    data/symptoms_new14353_right.jpeg
# 2     data/symptoms_new11623_left.jpeg
# 3     data/symptoms_new11162_left.jpeg
# 4    data/symptoms_new12042_right.jpeg
# 5     data/symptoms_new11183_left.jpeg
# 6    data/symptoms_new14251_right.jpeg
# 7    data/symptoms_new14811_right.jpeg
# 8     data/symptoms_new12839_left.jpeg
# 9    data/symptoms_new15898_right.jpeg
# 10     data/symptoms_new1050_left.jpeg
# 11   data/symptoms_new11819_right.jpeg
# 12    data/symptoms_new12630_left.jpeg
# 13    data/symptoms_new12831_left.jpeg
# 14   data/symptoms_new15886_right.jpeg
# 15    data/symptoms_new11647_left.jpeg
# 16    data/symptoms_new11847_left.jpeg
# 17   data/symptoms_new14045_right.jpeg
# 18   data/symptoms_new15530_right.jpeg
# 19    data/symptoms_new11505_left.jpeg
# 20   data/symptoms_new16412_right.jpeg
# 21    data/symptoms_new16351_left.jpeg
# 22   data/symptoms_new16510_right.jpeg
# 23   data/symptoms_new15095_right.jpeg
# 24    data/symptoms_new14936_left.jpeg
# 25    data/symptoms_new12101_left.jpeg
# 26   data/symptoms_new15029_right.jpeg
# 27    data/symptoms_new14834_left.jpeg
# 28   data/symptoms_new11417_right.jpeg
# 29    data/symptoms_new13002_left.jpeg
# ..                                 ...
# 565   data/symptoms_new12392_left.jpeg
# 566  data/symptoms_new13751_right.jpeg
# 567  data/symptoms_new13962_right.jpeg
# 568   data/symptoms_new14045_left.jpeg
# 569  data/symptoms_new10924_right.jpeg
# 570  data/symptoms_new10230_right.jpeg
# 571   data/symptoms_new16138_left.jpeg
# 572   data/symptoms_new13999_left.jpeg
# 573   data/symptoms_new1407_right.jpeg
# 574   data/symptoms_new11209_left.jpeg
# 575   data/symptoms_new1020_right.jpeg
# 576  data/symptoms_new15656_right.jpeg
# 577   data/symptoms_new15288_left.jpeg
# 578  data/symptoms_new12101_right.jpeg
# 579   data/symptoms_new15297_left.jpeg
# 580  data/symptoms_new16488_right.jpeg
# 581  data/symptoms_new14463_right.jpeg
# 582  data/symptoms_new16327_right.jpeg
# 583  data/symptoms_new14340_right.jpeg
# 584   data/symptoms_new1050_right.jpeg
# 585   data/symptoms_new11819_left.jpeg
# 586   data/symptoms_new12278_left.jpeg
# 587   data/symptoms_new15636_left.jpeg
# 588  data/symptoms_new13180_right.jpeg
# 589   data/symptoms_new12614_left.jpeg
# 590  data/symptoms_new11623_right.jpeg
# 591   data/symptoms_new14992_left.jpeg
# 592   data/symptoms_new15302_left.jpeg
# 593   data/symptoms_new15696_left.jpeg
# 594  data/symptoms_new14297_right.jpeg
#
# [595 rows x 1 columns]
